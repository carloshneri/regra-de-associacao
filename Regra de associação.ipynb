# %% [markdown]
# ## Regras de associação

# %% [markdown]
# As regras de associação é uma forma de relacionar dentro de um conjunto de items padrões de relacionamento em que X implica em Y.(X --> Y). As regras de associação podem ter diversos usos como verificar comportamento de clientes, campanha de marketing, gestão de estoque, definição de catálogo etc.</br>
#
# Algumas medidas podem ser tiradas qunado estamos trabalhando com a regra de associação como o suporte, confiança e lift que nos ajuda a ir criando alguns critérios para a formação das regras como por exemplo a criação de regras que satisfaça a um suporte minimo. Isso é importante já que o numero de regras cresce exponencialmente com o numero de itens da base.</br></br>
#
# **Suporte** mede a probabilidade de um determinada regra acontecer dentro do conjunto de dados.</br>
#
# **suporte** = Sup(X -> Y) = P(X u Y) = σ(X u Y)/n  onde n é o numero de transações.</br>
# Serve para eliminar as regras menos interessantes.</br>
#
# **Confiança** verifica a ocorrência da parte consequente da regra.</br>
# Conf(X -> Y) = P(X|Y) = σ(X u Y)/σ(X)</br>
#
# **Lift** O Lift é uma medida que indica a força de associação entre dois itens, levando em conta a frequência de ambos no conjunto de dados. É calculado dividindo a confiança da associação pelo suporte do segundo item.
#
# O Lift é usado para comparar a força da associação entre dois itens com a força esperada. Um valor de Lift maior que 1 indica uma associação positiva, ou seja, a ocorrência do antecedente aumenta a probabilidade do consequente.
#
# Lift(X -> Y) = Conf(X -> Y)/σ(Y) = σ(X u Y)/σ(X) * σ(Y)</br>

# %% [markdown]
# ###Etapas
#
#
# 1. Carregar as bibliotecas
# 2. Importar e verificar os dados
# 3. Pre processamento
#    * Limpeza dos dados
#    * Tranformação dos dados
# 5. Preparando o modelo
# 6. Criando as regras de associação.

# %% [markdown]
# ### Carregar as bibliotecas.

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.10/dist-packages (0.23.1)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (2.1.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.3.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (3.7.1)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# ### Importar os dados

# %%
url = 'https://raw.githubusercontent.com/higoramario/univesp-com360-mineracao-dados/main/market-basket-optimisation.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.read_csv(url, header=None)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Pré processamento dos dados.

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
len(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 7501

# %% [markdown]
# Limpeza dos dados. Primeiro remover os espaços brancos no inicio e fim das palavras

# %%
for index in df.columns:
  df[index] = df[index].str.strip()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Juntar os dados existentes na planilha para identificar a quantidade de itens distintos existe na tabela.

# %%
itens = df.melt()['value'].dropna().unique()
print(f"O total de itens distintos no dataframe = {len(itens)}")
# Out:
# O total de itens distintos no dataframe = 119
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# #### Identificar os registros que possuem mais que um item. Para as regras de associação é necessario que os registros possuam mais que um item.

# %% [markdown]
# Somando os itens diferentes de nulos

# %%
cesta_item = df.notna().apply(sum, axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
cesta_item.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0    20
# 1     3
# 2     1
# 3     2
# 4     5
# dtype: int64

# %% [markdown]
# Filtro dos registros com mais de um item para serem usados na regra de associação.

# %%
filtro=(cesta_item[:]>1).values.tolist()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df1=df.iloc[filtro]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Criando listas com os valores com mais de uma compra com as linhas do dataframe excluindo os valores nulos

# %%
lista_itens = [list(item.dropna()) for _, item in df1.iterrows()]
print(lista_itens)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grap
shallot'], ['soup', 'eggs'], ['mineral water', 'chocolate', 'low fat yogurt'], ['eggs', 'strawberries'], ['grated cheese', 'ground beef', 'spaghetti', 'mineral water', 'white wine'], ['eggs', 'cake', 'french fries'], ['burgers', 'spaghetti', 'milk', 'french fries', 'green tea'], ['mineral water', 'energy bar', 'butter', 'french fries'], ['burgers', 'grated cheese', 'herb & pepper', 'mineral water', 'eggs', 'cooking oil'], ['energy bar', 'energy drink'], ['chocolate', 'frozen smoothie'], ['asparagus', 'salad'], ['burgers', 'french fries', 'low fat yogurt', 'green tea'], ['burgers', 'herb & pepper', 'shrimp', 'pasta', 'spagh ...

# %% [markdown]
# ### Preparando o modelo

# %% [markdown]
# Criando um dataframe como OnehotEncoder.

# %%
te = TransactionEncoder()
te_ary = te.fit(lista_itens).transform(lista_itens)
df2 = pd.DataFrame(te_ary, columns=te.columns_)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df2.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    almonds  antioxydant juice  asparagus  avocado  babies food  bacon  \
# 0     True               True      False     True        False  False
# 1    False              False      False    False        False  False
# 2    False              False      False     True        False  False
# 3    False              False      False    False        False  False
# 4    False              False      False    False        False  False
#
#    barbecue sauce  black tea  blueberries  body spray  ...  turkey  \
# 0           False      False        False       False  ...   False
# 1           False      False        False       False  ...   False
# 2           False      False        False       False  ...    True
# 3           False      False        False       False  ...   False
# 4           False      False        False       False  ...   False
#
#    vegetables mix  water spray  white wine  whole weat flour  \
# 0            True        False       False              True
# 1           False        False       False             False
# 2           False        False       False             False
# 3           False        False       False             False
# 4           False        False       False             False
#
#    whole wheat pasta  whole wheat rice   yams  yogurt cake  zucchini
# 0              False             False   True        False     False
# 1              False             False  False        False     False
# 2              False             False  False        False     False
# 3              False              True  False        False     False
# 4               True             False  False        False     False
#
# [5 rows x 119 columns]

# %% [markdown]
# Criando uma ista de itens frequentes que possuem um suporte minimo.

# %%
min_support = 0.02
frequent_itemsets = apriori(df2, min_support= min_support, use_colnames=True)
frequent_itemsets.sort_values(by=['support'], ascending=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       support                               itemsets
# 35   0.294936                        (mineral water)
# 13   0.218897                                 (eggs)
# 50   0.218201                            (spaghetti)
# 9    0.201148                            (chocolate)
# 17   0.200104                         (french fries)
# ..        ...                                    ...
# 145  0.020706  (spaghetti, mineral water, chocolate)
# 147  0.020532       (spaghetti, mineral water, milk)
# 56   0.020358                           (white wine)
# 106  0.020358           (spaghetti, frozen smoothie)
# 30   0.020010                          (light cream)
#
# [148 rows x 2 columns]

# %% [markdown]
# ### criando as regras de associação

# %% [markdown]
# Criando as regras de associação onde usamos os itens frequentes que atendem ao suporte minimo anterior. <br>
# **metric:** é a metrica é definica entre: <br>
# *   'support',
# *   'confidence'
# *   'lift'
# *   'leverage'
# *   'conviction'
# *   'zhangs_metric'
#
# **min_thereshold:** é o valor minimos do parametro escolhido como metrica, funcionando como um filtro.

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                      antecedents      consequents  antecedent support  \
# 0                      (burgers)      (chocolate)            0.110318
# 1                      (burgers)           (eggs)            0.110318
# 2                      (burgers)   (french fries)            0.110318
# 3                      (burgers)      (green tea)            0.110318
# 4                      (burgers)           (milk)            0.110318
# ..                           ...              ...                 ...
# 93    (spaghetti, mineral water)    (ground beef)            0.077954
# 94  (ground beef, mineral water)      (spaghetti)            0.053419
# 95    (spaghetti, mineral water)           (milk)            0.077954
# 96             (spaghetti, milk)  (mineral water)            0.046285
# 97         (mineral water, milk)      (spaghetti)            0.062641
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.201148  0.022272    0.201893  1.003700  0.000082    1.000933
# 1             0.218897  0.037585    0.340694  1.556414  0.013436    1.184735
# 2             0.200104  0.028711    0.260252  1.300583  0.006635    1.081309
# 3             0.159910  0.022795    0.206625  1.292135  0.005154    1.058881
# 4             0.163390  0.023317    0.211356  1.293574  0.005292    1.060822
# ..                 ...       ...         ...       ...       ...         ...
# 93            0.124587  0.022272    0.285714  2.293296  0.012560    1.225579
# 94            0.218201  0.022272    0.416938  1.910800  0.010616    1.340851
# 95            0.163390  0.020532    0.263393  1.612054  0.007796    1.135762
# 96            0.294936  0.020532    0.443609  1.504083  0.006881    1.267209
# 97            0.218201  0.020532    0.327778  1.502184  0.006864    1.163007
#
#     zhangs_metric
# 0        0.004144
# 1        0.401826
# 2        0.259772
# 3        0.254121
# 4        0.255089
# ..            ...
# 93       0.611625
# 94       0.503559
# 95       0.411773
# 96       0.351408
# 97       0.356643
#
# [98 rows x 10 columns]

# %%
for rule in rules.iterrows():
  itens = list(rule[1])
  antecedente = list(itens[0])
  consequente = list(itens[1])
  print(f'{antecedente} --> {consequente}, suporte: {itens[4]:.3f}, confiança: {itens[5]:3f}')
# Out:
# ['chocolate'] --> ['burgers'], suporte: 0.022, confiança: 0.110727
# ['burgers'] --> ['chocolate'], suporte: 0.022, confiança: 0.201893
# ['eggs'] --> ['burgers'], suporte: 0.038, confiança: 0.171701
# ['burgers'] --> ['eggs'], suporte: 0.038, confiança: 0.340694
# ['burgers'] --> ['french fries'], suporte: 0.029, confiança: 0.260252
# ['french fries'] --> ['burgers'], suporte: 0.029, confiança: 0.143478
# ['green tea'] --> ['burgers'], suporte: 0.023, confiança: 0.142546
# ['burgers'] --> ['green tea'], suporte: 0.023, confiança: 0.206625
# ['burgers'] --> ['milk'], suporte: 0.023, confiança: 0.211356
# ['milk'] --> ['burgers'], suporte: 0.023, confiança: 0.142705
# ['mineral water'] --> ['burgers'], suporte: 0.032, confiança: 0.107965
# ['burgers'] --> ['mineral water'], suporte: 0.032, confiança: 0.288644
# ['spaghetti'] --> ['burgers'], suporte: 0.028, confiança: 0.128389
# ['burgers'] --> ['spaghetti'], suporte: 0.028, confiança: 0.253943
# ['eggs'] --> ['cake'], suporte: 0.025, confiança: 0.113672
# ['cake'] --> ['eggs'], suporte: 0.025, confiança: 0.246978
# ['cake'] --> ['french fries'], suporte: 0.023, confiança: 0.231434
# ['french fries'] --> ['cake'], suporte: 0.023, confiança: 0.116522
# ['cake'] --> ['mineral water'], suporte: 0.036, confiança: 0.355786
# ['mineral water'] --> ['cake'], suporte: 0.036, confiança: 0.121534
# ['spaghetti'] --> ['cake'], suporte: 0.024, confiança: 0.108453
# ['cake'] --> ['spaghetti'], suporte: 0.024, confiança: 0.234888
# ['chicken'] --> ['mineral water'], suporte: 0.030, confiança: 0.388636
# ['mineral water'] --> ['chicken'], suporte: 0.030, confiança: 0.100885
# ['spaghetti'] --> ['chicken'], suporte: 0.022, confiança: 0.102871
# ['chicken'] --> ['spaghetti'], suporte: 0.022, confiança: 0.293182
# ['eggs'] --> ['chocolate'], suporte: 0.043, confiança: 0.197933
# ['chocolate'] --> ['eggs'], suporte: 0.043, confiança: 0.215398
# ['escalope'] --> ['chocolate'], suporte: 0.023, confiança: 0.267206
# ['chocolate'] --> ['escalope'], suporte: 0.023, confiança: 0.114187
# ['chocolate'] --> ['french fries'], suporte: 0.045, confiança: 0.223183
# ['french fries'] --> ['chocolate'], suporte: 0.045, confiança: 0.224348
# ['chocolate'] --> ['frozen vegetables'], suporte: 0.030, confiança: 0.148789
# ['frozen vegetables'] --> ['chocolate'], suporte: 0.030, confiança: 0.247126
# ['green tea'] --> ['chocolate'], suporte: 0.031, confiança: 0.191513
# ['chocolate'] --> ['green tea'], suporte: 0.031, confiança: 0.152249
# ['ground beef'] --> ['chocolate'], suporte: 0.030, confiança: 0.241620
# ['chocolate'] --> ['ground beef'], suporte: 0.030, confiança: 0.149654
# ['chocolate'] --> ['milk'], suporte: 0.042, confiança: 0.208478
# ['milk'] --> ['chocolate'], suporte: 0.042, confiança: 0.256656
# ['mineral water'] --> ['chocolate'], suporte: 0.069, confiança: 0.233038
# ['chocolate'] --> ['mineral water'], suporte: 0.069, confiança: 0.341696
# ['olive oil'] --> ['chocolate'], suporte: 0.021, confiança: 0.261146
# ['chocolate'] --> ['olive oil'], suporte: 0.021, confiança: 0.106401
# ['chocolate'] --> ['pancakes'], suporte: 0.026, confiança: 0.128893
# ['pancakes'] --> ['chocolate'], suporte: 0.026, confiança: 0.221068
# ['shrimp'] --> ['chocolate'], suporte: 0.023, confiança: 0.258621
# ['chocolate'] --> ['shrimp'], suporte: 0.023, confiança: 0.116782
# ['spaghetti'] --> ['chocolate'], suporte: 0.051, confiança: 0.234450
# ['chocolate'] --> ['spaghetti'], suporte: 0.051, confiança: 0.254325
# ['mineral water'] --> ['cooking oil'], suporte: 0.026, confiança: 0.089086
# ['cooking oil'] --> ['mineral water'], suporte: 0.026, confiança: 0.401596
# ['spaghetti'] --> ['cooking oil'], suporte: 0.021, confiança: 0.094896
# ['cooking oil'] --> ['spaghetti'], suporte: 0.021, confiança: 0.316489
# ['eggs'] --> ['french fries'], suporte: 0.048, confiança: 0.217011
# ['french fries'] --> ['eggs'], suporte: 0.048, confiança: 0.237391
# ['eggs'] --> ['frozen vegetables'], suporte: 0.028, confiança: 0.129571
# ['frozen vegetables'] --> ['eggs'], suporte: 0.028, confiança: 0.234195
# ['eggs'] --> ['green tea'], suporte: 0.033, confiança: 0.151828
# ['green tea'] --> ['eggs'], suporte: 0.033, confiança: 0.207835
# ['ground beef'] --> ['eggs'], suporte: 0.026, confiança: 0.209497
# ['eggs'] --> ['ground beef'], suporte: 0.026, confiança: 0.119237
# ['eggs'] --> ['low fat yogurt'], suporte: 0.022, confiança: 0.100159
# ['low fat yogurt'] --> ['eggs'], suporte: 0.022, confiança: 0.238185
# ['eggs'] --> ['milk'], suporte: 0.040, confiança: 0.183625
# ['milk'] --> ['eggs'], suporte: 0.040, confiança: 0.246006
# ['eggs'] --> ['mineral water'], suporte: 0.066, confiança: 0.303657
# ['mineral water'] --> ['eggs'], suporte: 0.066, confiança: 0.225369
# ['eggs'] --> ['pancakes'], suporte: 0.028, confiança: 0.129571
# ['pancakes'] --> ['eggs'], suporte: 0.028, confiança: 0.241840
# ['spaghetti'] --> ['eggs'], suporte: 0.048, confiança: 0.218501
# ['eggs'] --> ['spaghetti'], suporte: 0.048, confiança: 0.217806
# ['eggs'] --> ['turkey'], suporte: 0.025, confiança: 0.116057
# ['turkey'] --> ['eggs'], suporte: 0.025, confiança: 0.320175
# ['escalope'] --> ['french fries'], suporte: 0.021, confiança: 0.248988
# ['french fries'] --> ['escalope'], suporte: 0.021, confiança: 0.106957
# ['escalope'] --> ['mineral water'], suporte: 0.022, confiança: 0.259109
# ['mineral water'] --> ['escalope'], suporte: 0.022, confiança: 0.075516
# ['french fries'] --> ['frozen vegetables'], suporte: 0.025, confiança: 0.124348
# ['frozen vegetables'] --> ['french fries'], suporte: 0.025, confiança: 0.205460
# ['green tea'] --> ['french fries'], suporte: 0.037, confiança: 0.232862
# ['french fries'] --> ['green tea'], suporte: 0.037, confiança: 0.186087
# ['milk'] --> ['french fries'], suporte: 0.031, confiança: 0.189563
# ['french fries'] --> ['milk'], suporte: 0.031, confiança: 0.154783
# ['mineral water'] --> ['french fries'], suporte: 0.044, confiança: 0.149263
# ['french fries'] --> ['mineral water'], suporte: 0.044, confiança: 0.220000
# ['french fries'] --> ['pancakes'], suporte: 0.026, confiança: 0.131304
# ['pancakes'] --> ['french fries'], suporte: 0.026, confiança: 0.224036
# ['spaghetti'] --> ['french fries'], suporte: 0.036, confiança: 0.165072
# ['french fries'] --> ['spaghetti'], suporte: 0.036, confiança: 0.180000
# ['mineral water'] --> ['frozen smoothie'], suporte: 0.026, confiança: 0.089676
# ['frozen smoothie'] --> ['mineral water'], suporte: 0.026, confiança: 0.334066
# ['spaghetti'] --> ['frozen smoothie'], suporte: 0.020, confiança: 0.093301
# ['frozen smoothie'] --> ['spaghetti'], suporte: 0.020, confiança: 0.257143
# ['ground beef'] --> ['frozen vegetables'], suporte: 0.022, confiança: 0.177374
# ['frozen vegetables'] --> ['ground beef'], suporte: 0.022, confiança: 0.182471
# ['milk'] --> ['frozen vegetables'], suporte: 0.031, confiança: 0.188498
# ['frozen vegetables'] --> ['milk'], suporte: 0.031, confiança: 0.254310
# ['mineral water'] --> ['frozen vegetables'], suporte: 0.047, confiança: 0.158112
# ['frozen vegetables'] --> ['mineral water'], suporte: 0.047, confiança: 0.385057
# ['shrimp'] --> ['frozen vegetables'], suporte: 0.022, confiança: 0.239464
# ['frozen vegetables'] --> ['shrimp'], suporte: 0.022, confiança: 0.179598
# ['spaghetti'] --> ['frozen vegetables'], suporte: 0.036, confiança: 0.166667
# ['frozen vegetables'] --> ['spaghetti'], suporte: 0.036, confiança: 0.300287
# ['frozen vegetables'] --> ['tomatoes'], suporte: 0.021, confiança: 0.173851
# ['tomatoes'] --> ['frozen vegetables'], suporte: 0.021, confiança: 0.244939
# ['mineral water'] --> ['grated cheese'], suporte: 0.023, confiança: 0.077286
# ['grated cheese'] --> ['mineral water'], suporte: 0.023, confiança: 0.352151
# ['spaghetti'] --> ['grated cheese'], suporte: 0.022, confiança: 0.098884
# ['grated cheese'] --> ['spaghetti'], suporte: 0.022, confiança: 0.333333
# ['green tea'] --> ['milk'], suporte: 0.023, confiança: 0.143634
# ['milk'] --> ['green tea'], suporte: 0.023, confiança: 0.140575
# ['mineral water'] --> ['green tea'], suporte: 0.041, confiança: 0.137463
# ['green tea'] --> ['mineral water'], suporte: 0.041, confiança: 0.253536
# ['green tea'] --> ['pancakes'], suporte: 0.021, confiança: 0.133841
# ['pancakes'] --> ['green tea'], suporte: 0.021, confiança: 0.182493
# ['spaghetti'] --> ['green tea'], suporte: 0.035, confiança: 0.158692
# ['green tea'] --> ['spaghetti'], suporte: 0.035, confiança: 0.216540
# ['ground beef'] --> ['herb & pepper'], suporte: 0.021, confiança: 0.167598
# ['herb & pepper'] --> ['ground beef'], suporte: 0.021, confiança: 0.342857
# ['ground beef'] --> ['milk'], suporte: 0.029, confiança: 0.230447
# ['milk'] --> ['ground beef'], suporte: 0.029, confiança: 0.175719
# ['ground beef'] --> ['mineral water'], suporte: 0.053, confiança: 0.428771
# ['mineral water'] --> ['ground beef'], suporte: 0.053, confiança: 0.181121
# ['spaghetti'] --> ['ground beef'], suporte: 0.051, confiança: 0.234450
# ['ground beef'] --> ['spaghetti'], suporte: 0.051, confiança: 0.410615
# ['mineral water'] --> ['herb & pepper'], suporte: 0.022, confiança: 0.075516
# ['herb & pepper'] --> ['mineral water'], suporte: 0.022, confiança: 0.365714
# ['spaghetti'] --> ['herb & pepper'], suporte: 0.021, confiança: 0.097289
# ['herb & pepper'] --> ['spaghetti'], suporte: 0.021, confiança: 0.348571
# ['mineral water'] --> ['low fat yogurt'], suporte: 0.031, confiança: 0.106195
# ['low fat yogurt'] --> ['mineral water'], suporte: 0.031, confiança: 0.340265
# ['mineral water'] --> ['milk'], suporte: 0.063, confiança: 0.212389
# ['milk'] --> ['mineral water'], suporte: 0.063, confiança: 0.383387
# ['olive oil'] --> ['milk'], suporte: 0.022, confiança: 0.271762
# ['milk'] --> ['olive oil'], suporte: 0.022, confiança: 0.136315
# ['milk'] --> ['pancakes'], suporte: 0.022, confiança: 0.132055
# ['pancakes'] --> ['milk'], suporte: 0.022, confiança: 0.183976
# ['shrimp'] --> ['milk'], suporte: 0.023, confiança: 0.252874
# ['milk'] --> ['shrimp'], suporte: 0.023, confiança: 0.140575
# ['spaghetti'] --> ['milk'], suporte: 0.046, confiança: 0.212121
# ['milk'] --> ['spaghetti'], suporte: 0.046, confiança: 0.283280
# ['mineral water'] --> ['olive oil'], suporte: 0.036, confiança: 0.122124
# ['olive oil'] --> ['mineral water'], suporte: 0.036, confiança: 0.439490
# ['mineral water'] --> ['pancakes'], suporte: 0.044, confiança: 0.149263
# ['pancakes'] --> ['mineral water'], suporte: 0.044, confiança: 0.375371
# ['salmon'] --> ['mineral water'], suporte: 0.022, confiança: 0.415584
# ['mineral water'] --> ['salmon'], suporte: 0.022, confiança: 0.075516
# ['mineral water'] --> ['shrimp'], suporte: 0.031, confiança: 0.104425
# ['shrimp'] --> ['mineral water'], suporte: 0.031, confiança: 0.339080
# ['soup'] --> ['mineral water'], suporte: 0.030, confiança: 0.466307
# ['mineral water'] --> ['soup'], suporte: 0.030, confiança: 0.102065
# ['spaghetti'] --> ['mineral water'], suporte: 0.078, confiança: 0.357257
# ['mineral water'] --> ['spaghetti'], suporte: 0.078, confiança: 0.264307
# ['mineral water'] --> ['tomatoes'], suporte: 0.032, confiança: 0.107965
# ['tomatoes'] --> ['mineral water'], suporte: 0.032, confiança: 0.370445
# ['mineral water'] --> ['turkey'], suporte: 0.025, confiança: 0.084956
# ['turkey'] --> ['mineral water'], suporte: 0.025, confiança: 0.315789
# ['mineral water'] --> ['whole wheat rice'], suporte: 0.026, confiança: 0.089086
# ['whole wheat rice'] --> ['mineral water'], suporte: 0.026, confiança: 0.358670
# ['spaghetti'] --> ['olive oil'], suporte: 0.030, confiança: 0.137161
# ['olive oil'] --> ['spaghetti'], suporte: 0.030, confiança: 0.365180
# ['spaghetti'] --> ['pancakes'], suporte: 0.033, confiança: 0.150718
# ['pancakes'] --> ['spaghetti'], suporte: 0.033, confiança: 0.280415
# ['spaghetti'] --> ['shrimp'], suporte: 0.028, confiança: 0.126794
# ['shrimp'] --> ['spaghetti'], suporte: 0.028, confiança: 0.304598
# ['spaghetti'] --> ['tomatoes'], suporte: 0.027, confiança: 0.125199
# ['tomatoes'] --> ['spaghetti'], suporte: 0.027, confiança: 0.317814
# ['spaghetti'] --> ['turkey'], suporte: 0.022, confiança: 0.098884
# ['turkey'] --> ['spaghetti'], suporte: 0.022, confiança: 0.271930
# ['spaghetti', 'mineral water'] --> ['chocolate'], suporte: 0.021, confiança: 0.265625
# ['spaghetti', 'chocolate'] --> ['mineral water'], suporte: 0.021, confiança: 0.404762
# ['mineral water', 'chocolate'] --> ['spaghetti'], suporte: 0.021, confiança: 0.301266
# ['spaghetti'] --> ['mineral water', 'chocolate'], suporte: 0.021, confiança: 0.094896
# ['mineral water'] --> ['spaghetti', 'chocolate'], suporte: 0.021, confiança: 0.070206
# ['chocolate'] --> ['spaghetti', 'mineral water'], suporte: 0.021, confiança: 0.102941
# ['spaghetti', 'ground beef'] --> ['mineral water'], suporte: 0.022, confiança: 0.435374
# ['spaghetti', 'mineral water'] --> ['ground beef'], suporte: 0.022, confiança: 0.285714
# ['ground beef', 'mineral water'] --> ['spaghetti'], suporte: 0.022, confiança: 0.416938
# ['spaghetti'] --> ['ground beef', 'mineral water'], suporte: 0.022, confiança: 0.102073
# ['ground beef'] --> ['spaghetti', 'mineral water'], suporte: 0.022, confiança: 0.178771
# ['mineral water'] --> ['spaghetti', 'ground beef'], suporte: 0.022, confiança: 0.075516
# ['spaghetti', 'mineral water'] --> ['milk'], suporte: 0.021, confiança: 0.263393
# ['spaghetti', 'milk'] --> ['mineral water'], suporte: 0.021, confiança: 0.443609
# ['mineral water', 'milk'] --> ['spaghetti'], suporte: 0.021, confiança: 0.327778
# ['spaghetti'] --> ['mineral water', 'milk'], suporte: 0.021, confiança: 0.094099
# ['mineral water'] --> ['spaghetti', 'milk'], suporte: 0.021, confiança: 0.069617
# ['milk'] --> ['spaghetti', 'mineral water'], suporte: 0.021, confiança: 0.125666
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rul = rules.iloc[(rules['antecedents']==frozenset({'spaghetti'})).values.tolist()]
rul
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#